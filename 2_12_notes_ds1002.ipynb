# %% [markdown]
# <a href="https://colab.research.google.com/github/carter-grohe/ds1002s24cg/blob/main/2_12_notes_ds1002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notes 2/12/2024 *Find original notebook

# %%
import numpy as np

# %%
b_list = [[9,8,7,6,5,4,3],[1,2,3,4,5,6,7]]
y = np.array(b_list)
y
# Out:
# array([[9, 8, 7, 6, 5, 4, 3],
#        [1, 2, 3, 4, 5, 6, 7]])

# %%
y.shape #shape of array
y.ndim # dimensions of array
np.sort(y) # sort in increasing order
# Out:
# 2

# %%
z = np.array([1,2,3,4,5])
z < 3
z > 3
# Out:
# array([False, False, False,  True,  True])

# %%
z[z > 3] # masks array to only show the values that are True in the booleans above
# Out:
# array([4, 5])

# %%
# arrays can be added together,  multiplied, added to, etc. math applies.

a = np.array ([1,2,3,4,5])
b = np.array ([6,7,8,9,10])
a + b
a * 10
# Out:
# array([10, 20, 30, 40, 50])

# %%
# Images are also numerical data
# !pip install scikit-image matplotlib

# %%
from skimage import io

photo = io.imread('CASH.png') #gang
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (300, 810, 4)

# %%
photo[34,21,] # will supposedly show RGB of pixel). colon goes between range and so it will give third/fourth coordinate when prompted
# Out:
# array([ 27,  27,  27, 255], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
plt.imshow(photo[:, ::1]) #not needed, expert way of flipping the image, etc. etc. messing with number will compact image horizontally

# %%
photo_red = plt.imshow(photo[::,::,0])
